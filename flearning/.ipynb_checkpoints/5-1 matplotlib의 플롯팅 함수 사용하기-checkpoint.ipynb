# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# %matplotlib nbagg 
# nbagg는 interactive하게 조작 가능,
# inline은 특정 cell에서 plot생성하고 이후에 조작 불가

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0,100,10))

# %%
s
# Out:
# 0     0.513534
# 10    1.742057
# 20    2.705045
# 30    4.003725
# 40    4.332972
# 50    4.008706
# 60    4.341216
# 70    3.399581
# 80    2.695746
# 90    3.381047
# dtype: float64

# %%
s.plot()
# plt.plot(s)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df = pd.DataFrame(np.random.randn(10,4).cumsum(axis=0),
                 columns=["A","B","C","D"],
                 index=np.arange(0,100,10))

# %%
df
# Out:
#            A         B         C         D
# 0   0.691777  1.478330  0.007115 -1.813582
# 10 -0.632838  1.081400 -0.022744 -0.739810
# 20  1.335631  0.161557 -0.810740  0.584354
# 30  0.005457 -1.873703 -1.535242  0.573839
# 40 -1.471328 -2.618433 -1.767751  1.009403
# 50  0.173365 -3.497344 -1.424233  1.504664
# 60  0.459874 -3.518969 -2.410081  1.176753
# 70 -0.219050 -2.961876 -1.634515  1.429764
# 80  0.168450 -4.302702 -1.846017  0.743878
# 90 -1.442423 -3.565399 -2.356127 -0.666656

# %%
df.plot()
# plt.plot(df)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df["B"].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s2 = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))

# %%
s2
# Out:
# a    0.287480
# b    0.804471
# c    0.479838
# d    0.780576
# e    0.502591
# f    0.572644
# g    0.622627
# h    0.472216
# i    0.119357
# j    0.561773
# k    0.975503
# l    0.604596
# m    0.473177
# n    0.342074
# o    0.337107
# p    0.083535
# dtype: float64

# %%
s2.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s2.plot(kind="barh")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2 = pd.DataFrame(np.random.rand(6,4),
                  index=["one","two","three","four","five","six"],
                  columns=pd.Index(["A","B","C","D"], name="Genus"))

# %%
df2
# Out:
# Genus         A         B         C         D
# one    0.644053  0.904462  0.389258  0.017609
# two    0.196664  0.580658  0.900120  0.259386
# three  0.541621  0.489242  0.834255  0.756521
# four   0.577390  0.867317  0.041905  0.016832
# five   0.593107  0.499914  0.259899  0.869874
# six    0.295160  0.662618  0.430594  0.554856

# %%
df2.plot(kind="bar")
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind="barh", stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3 = pd.Series(np.random.normal(0, 1, size=200))

# %%
s3
# Out:
# 0      0.861850
# 1     -1.145485
# 2     -1.204350
# 3      0.442578
# 4      0.378869
# 5     -0.492676
# 6      0.747539
# 7      1.099368
# 8     -0.632967
# 9      0.362333
# 10     0.532101
# 11    -0.566578
# 12     1.637044
# 13     0.318895
# 14    -0.197820
# 15     0.684371
# 16    -0.448743
# 17    -0.848274
# 18     0.415530
# 19     2.299077
# 20     1.570574
# 21    -0.187746
# 22     1.021002
# 23    -0.475211
# 24    -0.645508
# 25    -0.864304
# 26    -0.173128
# 27     0.251995
# 28    -0.395023
# 29    -0.133438
#          ...
# 170   -1.291842
# 171   -1.304935
# 172   -0.448356
# 173   -0.269728
# 174    0.429582
# 175    1.099631
# 176    2.495650
# 177    1.455660
# 178   -1.481892
# 179    0.865066
# 180    0.019462
# 181    0.121442
# 182    0.748841
# 183   -0.611058
# 184   -1.257697
# 185   -0.771008
# 186    2.922021
# 187    0.070798
# 188    0.329528
# 189    0.818985
# 190    0.264705
# 191   -0.430108
# 192   -0.355485
# 193    0.303643
# 194   -1.748140
# 195    0.924562
# 196   -0.089597
# 197   -0.467100
# 198    0.547903
# 199   -1.006672
# Length: 200, dtype: float64

# %%
s3.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3.hist(bins=50)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3.hist(bins=100, density=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
s3.hist(bins=100)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.random.normal(1,1,size=(100,1))
x2 = np.random.normal(-2,4,size=(100,1))
x = np.concatenate((x1,x2), axis=1)

# %%
x
# Out:
# array([[ 2.64227444e+00, -8.77668921e+00],
#        [ 1.51073036e+00, -1.91062234e+00],
#        [ 1.91037559e+00,  5.57016236e+00],
#        [-7.33502712e-01, -8.72492846e+00],
#        [ 2.25717833e+00, -5.97488001e-01],
#        [ 8.11245260e-01, -4.83253855e+00],
#        [ 2.10244576e+00, -3.50726363e+00],
#        [ 8.86413216e-01, -2.26440042e+00],
#        [ 7.49228751e-01,  1.77346655e+00],
#        [ 2.76416136e-01,  5.93198246e+00],
#        [ 1.87388972e+00,  6.46439382e+00],
#        [-4.86952938e-01,  3.38182634e+00],
#        [ 1.15376089e+00, -3.13827714e+00],
#        [ 1.79699243e+00, -3.71655128e+00],
#        [ 1.22082670e+00, -4.51435621e+00],
#        [ 1.29115184e+00, -7.71542535e+00],
#        [ 1.69252242e+00, -1.50830196e+00],
#        [ 4.44735083e-02, -6.38633987e+00],
#        [ 2.00473934e+00,  2.87920940e-01],
#        [-1.29386581e+00, -4.09891342e+00],
#        [ 8.17709008e-01, -5.00886324e+00],
#        [-1.88428700e-01,  3.91644893e+00],
#        [-1.08141625e-01, -1.20755747e+00],
#        [ 1.29054450e+00, -9.40262175e-01],
#        [ 1.35631945e+00, -9.83789322e+00],
#        [ 1.79569320e+00, -8.84672204e+00],
#        [ 8.76438661e-01, -1.10357235e+01],
#        [ 4.28654421e-01,  3.49152141e+00],
#        [ 1.05264181e+00, -6.21832277e+00],
#        [ 1.34592488e+00,  4.75137549e+00],
#        [ 8.97967833e-01, -1.99721694e-01],
#        [ 3.93698529e-01, -8.44580696e+00],
#        [ 1.69522498e+00, -2.99146801e+00],
#        [ 1.84353191e+00,  3.95890068e+00],
#        [ 1.10221556e+00, -3.76586381e+00],
#        [ 1.26770411e+00,  1.78084037e+00],
#        [-3.85161620e-01, -8.66078357e+00],
#        [-3.85709336e-01, -5.98437756e+00],
#        [ 4.13741187e-01, -1.71948553e+00],
#        [ 1.28600200e+00,  6.99523185e+00],
#        [ 1.05738672e+00, -1.89275533e-01],
#        [ 7.89184263e-01,  4.96060560e+00],
#        [ 2.13688379e+00, -1.39686978e+00],
#        [ 1.81660207e+00, -1.34638691e+00],
#        [ 2.62736186e+00, -2.17168225e+00],
#        [ 1.84097599e-01, -1.60900124e-01],
#        [ 2.03145802e+00, -5.55786809e+00],
#        [ 2.20950387e+00,  2.41479970e+00],
#        [ 1.66240729e+00, -1.02509848e+01],
#        [ 3.22021533e-02, -4.26382687e+00],
#        [ 1.52369104e+00, -7.14492217e+00],
#        [-7.09443947e-01, -1.43423360e-02],
#        [ 5.40427081e-01, -1.59002288e+00],
#        [ 4.20943715e-01, -7.20885940e+00],
#        [ 1.26558275e+00, -7.13159824e+00],
#        [ 6.15350659e-01,  4.02281273e+00],
#        [ 1.19066941e+00, -4.21502790e-01],
#        [ 9.55516900e-01,  9.26665800e-01],
#        [ 1.58531661e+00, -6.64827099e+00],
#        [ 2.53669629e-01,  6.90625321e-02],
#        [ 1.93161049e+00, -7.59743043e-01],
#        [ 1.01473894e+00, -9.29538637e+00],
#        [-2.30944297e-01, -7.40082290e+00],
#        [ 9.15301667e-01,  2.36066207e+00],
#        [ 2.40428611e+00,  3.36684269e-01],
#        [ 2.53755292e+00, -3.49829918e+00],
#        [ 1.69085283e+00, -3.16339103e+00],
#        [ 2.29478576e+00,  4.23067419e+00],
#        [ 1.37571157e+00, -1.27799880e+00],
#        [ 7.42153087e-01, -1.16032243e+01],
#        [ 1.00389444e+00,  4.13804809e+00],
#        [-7.61759956e-01, -3.45190768e+00],
#        [-4.20489118e-01, -4.96469859e+00],
#        [ 1.73032368e+00, -6.33154278e-01],
#        [ 1.93009898e-02, -1.14703465e+00],
#        [ 2.09999874e+00,  3.36278940e+00],
#        [ 8.10661842e-01,  4.95143981e-01],
#        [ 2.01764418e+00,  8.28440461e-01],
#        [ 1.11831061e+00, -5.98996963e+00],
#        [ 2.14423780e+00,  2.98172354e+00],
#        [-7.56782636e-01, -6.45789449e+00],
#        [ 1.26092808e+00, -1.71953293e+01],
#        [ 1.64562336e+00, -3.76008600e-01],
#        [ 1.95841631e+00,  4.82684843e+00],
#        [ 6.80753689e-01,  6.44077921e-02],
#        [-5.68960191e-01,  3.12920674e+00],
#        [-4.83224678e-01,  2.87398489e+00],
#        [ 1.66452651e+00,  8.00097678e+00],
#        [ 3.27222783e-01, -4.53415003e-01],
#        [ 1.15514064e+00, -6.41883190e-01],
#        [ 6.00808014e-01,  2.18394472e+00],
#        [-2.12796952e-01, -8.65330268e+00],
#        [ 1.97797849e+00, -7.43097790e-01],
#        [ 1.06031691e+00,  1.18022328e-01],
#        [ 1.71582490e-02, -3.04015801e-01],
#        [ 1.56694814e+00, -1.11164221e+00],
#        [ 9.57791106e-01,  2.31721381e+00],
#        [ 1.74676481e+00, -5.12148557e+00],
#        [-1.83967337e-01, -4.79125428e+00],
#        [-2.57650454e-01, -5.81599159e-01]])

# %%
df3 = pd.DataFrame(x, columns=["x1","x2"])

# %%
df3
# Out:
#           x1         x2
# 0   2.642274  -8.776689
# 1   1.510730  -1.910622
# 2   1.910376   5.570162
# 3  -0.733503  -8.724928
# 4   2.257178  -0.597488
# 5   0.811245  -4.832539
# 6   2.102446  -3.507264
# 7   0.886413  -2.264400
# 8   0.749229   1.773467
# 9   0.276416   5.931982
# 10  1.873890   6.464394
# 11 -0.486953   3.381826
# 12  1.153761  -3.138277
# 13  1.796992  -3.716551
# 14  1.220827  -4.514356
# 15  1.291152  -7.715425
# 16  1.692522  -1.508302
# 17  0.044474  -6.386340
# 18  2.004739   0.287921
# 19 -1.293866  -4.098913
# 20  0.817709  -5.008863
# 21 -0.188429   3.916449
# 22 -0.108142  -1.207557
# 23  1.290545  -0.940262
# 24  1.356319  -9.837893
# 25  1.795693  -8.846722
# 26  0.876439 -11.035723
# 27  0.428654   3.491521
# 28  1.052642  -6.218323
# 29  1.345925   4.751375
# ..       ...        ...
# 70  1.003894   4.138048
# 71 -0.761760  -3.451908
# 72 -0.420489  -4.964699
# 73  1.730324  -0.633154
# 74  0.019301  -1.147035
# 75  2.099999   3.362789
# 76  0.810662   0.495144
# 77  2.017644   0.828440
# 78  1.118311  -5.989970
# 79  2.144238   2.981724
# 80 -0.756783  -6.457894
# 81  1.260928 -17.195329
# 82  1.645623  -0.376009
# 83  1.958416   4.826848
# 84  0.680754   0.064408
# 85 -0.568960   3.129207
# 86 -0.483225   2.873985
# 87  1.664527   8.000977
# 88  0.327223  -0.453415
# 89  1.155141  -0.641883
# 90  0.600808   2.183945
# 91 -0.212797  -8.653303
# 92  1.977978  -0.743098
# 93  1.060317   0.118022
# 94  0.017158  -0.304016
# 95  1.566948  -1.111642
# 96  0.957791   2.317214
# 97  1.746765  -5.121486
# 98 -0.183967  -4.791254
# 99 -0.257650  -0.581599
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3["x1"], df3["x2"])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df3["x1"].corr(df3["x2"])
# Out:
# 0.11807853608979658
