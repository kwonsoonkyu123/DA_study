# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import matplotlib

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax1 = fig.add_subplot(2,2,1) # 2개의행 2개의열

# %%
ax2 = fig.add_subplot(2,2,2)

# %%
ax3 = fig.add_subplot(2,2,3)
ax4 = fig.add_subplot(2,2,4)

# %%
import numpy as np
import pandas as pd

# %%
plt.plot(np.random.randn(50).cumsum()) # axes를 지정하지 않으면 빈 axes중 가장 마지막에 추가함

# %%
ax1.hist(np.random.randn(100), bins=20)
# Out:
# (array([ 2.,  0.,  2.,  3.,  2.,  2.,  3., 14.,  6.,  9., 11.,  5.,  9.,
#          7.,  8.,  5.,  8.,  2.,  1.,  1.]),
#  array([-2.65779433, -2.41169438, -2.16559444, -1.9194945 , -1.67339456,
#         -1.42729461, -1.18119467, -0.93509473, -0.68899478, -0.44289484,
#         -0.1967949 ,  0.04930505,  0.29540499,  0.54150493,  0.78760488,
#          1.03370482,  1.27980476,  1.5259047 ,  1.77200465,  2.01810459,
#          2.26420453]),
#  <a list of 20 Patch objects>)

# %%
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
fig, axes = plt.subplots(2,3) #2행 3열 subplots
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027376CD04E0>,
# ...
#       dtype=object)

# %%
axes[1,2].plot()
# Out:
# []

# %%
plt.plot(np.random.randn(30), color="g", marker="o", linestyle="--") # o 는 동그라미

# %%
plt.plot(np.random.randn(30), "go--") # k.-, go-- 등은 color marking linestyle 순서대로

# %%
fig, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = pd.Series(np.random.rand(16), index=list("abcdefghijklmnop"))

# %%
data.plot(kind="bar", ax=axes[0], color="k", alpha=0.7)

# %%
data.plot(kind="barh", ax=axes[1], color="g", alpha=0.3)

# %%
fig = plt.figure()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax = fig.add_subplot(111)

# %%
ax.plot(np.random.randn(1000).cumsum())

# %%
ax.set_xticks([0, 250, 500, 750, 1000])

# %%
labels = ax.set_xticklabels(["one","two","three","four","five"],
                           rotation=30, fontsize="small")

# %%
ax.set_title("Random walk plot")
# Out:
# Text(0.5,1,'Random walk plot')

# %%
ax.set_xlabel("Stages")
ax.set_ylabel("Values")
# Out:
# Text(44.4028,0.5,'Values')

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
ax.plot(np.random.randn(1000).cumsum(), "k", label="one")
ax.plot(np.random.randn(1000).cumsum(), "r", label="two")
ax.plot(np.random.randn(1000).cumsum(), "b", label="three")

# %%
ax.legend(loc="best") # best는 최적의 위치에 자동으로 범주 입력, topright 등등 사용 가능

# %%
ax.get_xlim()
# Out:
# (-49.95, 1048.95)

# %%
ax.set_xlim([100,900])
# Out:
# (100, 900)

# %%
ax.set_ylim([-100,100])
# Out:
# (-100, 100)
